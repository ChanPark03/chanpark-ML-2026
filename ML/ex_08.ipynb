# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.src.backend.jax.image import resize
from keras.src.datasets import mnist

from tmp.build_project1_portfolio import X_test, y_test

# %%
mnist = tf.keras.datasets.mnist.load_data()

# %%
data = mnist[0][0]
print(data.shape)
# Out:
# (60000, 28, 28)

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train.shape
y_train.shape
# Out:
# (60000,)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Input(shape=(28*28,)))
model.add(tf.keras.layers.Dense(units=512, activation='relu', name='Hidden_1'))
model.add(tf.keras.layers.Dense(units=256, activation='relu', name='Hidden_2'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax', name='Hidden_3'))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_1 (Dense)                │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_2 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_3 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 535,818 (2.04 MB)
#  Trainable params: 535,818 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X_images = X_train.reshape((60000, 28*28))
ex1 = X_images[0] / 255
type(ex1.dtype)
# Out:
# numpy.dtypes.Float64DType

# %%
X_images_norm = (X_images / 255).astype('float32')

# %%
X_images_test =  X_test.reshape((10000, 28*28))

# %%
X_images_test_norm = (X_images_test / 255).astype('float32')

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(X_images_norm, y_train, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9817 - loss: 0.0745
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9965 - loss: 0.0131
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9974 - loss: 0.0088
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9979 - loss: 0.0069
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9978 - loss: 0.0064
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9985 - loss: 0.0052
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9984 - loss: 0.0055
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9989 - loss: 0.0035
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9984 - loss: 0.0051
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9992 - loss: 0.0028
# Epoch 11/20
# ...

# %%
model.save("MNIST_20260626_15.keras")

# %%
model.evaluate(X_images_test, y_test    )
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9796 - loss: 51.3896
# [51.38957595825195, 0.9796000123023987]

# %%
import cv2

# %%
img = cv2.imread("digit4.png", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resize_img = cv2.resize(img, (28,28))

# %%
cv2.imshow("IMAGE", resize_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resize_img =resize_img.astype('float32')

# %%
inverse_img = 255 - resize_img
cv2.imshow("IMAGE", inverse_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
inverse_img_norm = inverse_img / 255

# %%
result = model.predict(inverse_img_norm.reshape(1, 784))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step

# %%
print(result)
# Out:
# [[0.00000000e+00 1.03463304e-29 6.81149936e-25 1.00000000e+00
#   0.00000000e+00 5.84775654e-34 0.00000000e+00 1.18173897e-18
#   8.22088560e-38 4.40773848e-35]]

# %%
print(result.argmax())
# Out:
# 3
